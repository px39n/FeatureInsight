# %%
#!pip install FeatureInsight -U
#from FeatureInsight import struct_Investigation,univar_dis,bivar_dis
import sys 
sys.path.append("C:/Users/isxzl/OneDrive/Code/FeatureInsight")
from FeatureInsight import struct_Investigation,univar_dis,bivar_dis


import pandas as pd
from sklearn.pipeline import Pipeline
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os
from PIL import Image
import cv2
from tqdm import tqdm
from tabulate import tabulate
import klib
from FeatureInsight import struct_Investigation,univar_dis,bivar_dis

# %%
df = pd.read_csv('../FeatureInsight/dataset.csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       44    technician    single  secondary      no       29     yes   no
# 1       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 2       57   blue-collar   married    primary      no       52     yes   no
# 3       32   blue-collar    single    primary      no       23     yes  yes
# 4       39    management    single   tertiary      no      255     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 12148   34   blue-collar    single  secondary      no     1475     yes   no
# 12149   53    management   married   tertiary      no      583      no   no
# 12150   73       retired   married  secondary      no     2850      no   no
# 12151   71       retired  divorced    primary      no     1729      no   no
# 12152   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
a=struct_Investigation(df)  
df.head()
# Out:
# C:\Users\isxzl\OneDrive\Code\FeatureInsight\FeatureInsight\structure_Investigation.py:55: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.img_list=[]
# There are 12153 instances, 17 cols in total
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 241.87it/s]
#    age           job   marital  education default  balance housing loan  \
# 0   44    technician    single  secondary      no       29     yes   no
# 1   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 2   57   blue-collar   married    primary      no       52     yes   no
# 3   32   blue-collar    single    primary      no       23     yes  yes
# 4   39    management    single   tertiary      no      255     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
# Out:
# +------------+---------+------------------+-----------------------+--------------+---------------------------------------------+
# | variable   | dtype   | measure_scales   | Unique Count          | Null Count   | thumbnail                                   |
# |------------+---------+------------------+-----------------------+--------------+---------------------------------------------|
# | age        | int64   | Categorical Data | 73(0.60%) of total    | 0(0.0%)      | [46, 60, 41]                                |
# | job        | {'str'} | Categorical Data | 12(0.10%) of total    | 0(0.0%)      | ['technician', 'blue-collar', 'technician'] |
# | marital    | {'str'} | Categorical Data | 3(0.02%) of total     | 0(0.0%)      | ['single', 'single', 'single']              |
# | education  | {'str'} | Categorical Data | 4(0.03%) of total     | 0(0.0%)      | ['tertiary', 'secondary', 'secondary']      |
# ...

# %%
# Out:
#              dtype    measure_scales           Unique Count Null Count  \
# variable
# age          int64  Categorical Data     73(0.60%) of total    0(0.0%)
# job        {'str'}  Categorical Data     12(0.10%) of total    0(0.0%)
# marital    {'str'}  Categorical Data      3(0.02%) of total    0(0.0%)
# education  {'str'}  Categorical Data      4(0.03%) of total    0(0.0%)
# default    {'str'}  Categorical Data      2(0.02%) of total    0(0.0%)
# balance      int64    numerical Data  4141(34.07%) of total    0(0.0%)
# housing    {'str'}  Categorical Data      2(0.02%) of total    0(0.0%)
# loan       {'str'}  Categorical Data      2(0.02%) of total    0(0.0%)
# contact    {'str'}  Categorical Data      3(0.02%) of total    0(0.0%)
# day          int64  Categorical Data     31(0.26%) of total    0(0.0%)
# month      {'str'}  Categorical Data     12(0.10%) of total    0(0.0%)
# duration     int64  Categorical Data   1145(9.42%) of total    0(0.0%)
# ...

# %%
PrintableDataFrame(a.sort_values(by='Unique Count', ascending=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 PrintableDataFrame(a.sort_values(by='Unique Count', ascending=False))
#
# NameError: name 'PrintableDataFrame' is not defined

# %%
a.sort_values(by='Unique Count', ascending=False)

# %%
a
